# %%
import sys
import glob
import os
import re
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import datetime
# %matplotlib inline
# Out:
# /opt/conda/envs/python2/lib/python2.7/site-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')

# %%
def sum_throughput(trace):
    s = []
    for t in trace:
        trace = pd.read_table(t, header=None, sep=(","),names=("seconds", "rate"))
        if len(s) == 0: s = trace
        else: s += trace
    return s

# %%
fig = plt.figure()
ax = fig.add_subplot(111)

s = sum_throughput(glob.glob("mantle-proxy-issdm*.csv"))
ax.plot(range(0, len(s['rate'])), s['rate'], 
        'r-', marker='o', linewidth=2.0, label="Mantle")

#s = sum_throughput(glob.glob("2seq-baseline-issdm*.csv"))
#ax.plot(range(0, len(s['rate'])), s['rate'], 
#        'b-', marker='o', linewidth=2.0, label="2 Sequencers")

#s = sum_throughput(glob.glob("3seq-baseline-issdm*.csv"))
#ax.plot(range(0, len(s['rate'])), s['rate'], 
#        'g-', marker='o', linewidth=2.0, label="3 Sequencers")

#s = sum_throughput(glob.glob("4seq-baseline-issdm*.csv"))
#ax.plot(range(0, len(s['rate'])), s['rate'], 
#        'y-', marker='o', linewidth=2.0, label="4 Sequencers")

#s = sum_throughput(glob.glob("5seq-baseline-issdm*.csv"))
#ax.plot(range(0, len(s['rate'])), s['rate'], 
#        'o-', marker='o', linewidth=2.0, label="5 Sequencers")

s = sum_throughput(glob.glob("../results-baseline/6seq-baseline-issdm*.csv"))
ax.plot(range(0, len(s['rate'])), s['rate'], 
        'b-', marker='o', linewidth=2.0, label="Baseline")

#ax.set_ylim(0, 5000)
ax.set_xlabel("seconds")
ax.set_ylabel("Operations per second")
lgd = ax.legend(loc='center', bbox_to_anchor=(1.5, 0.8))

# %%
# Take the measurements between 10 and 40
s = sum_throughput(glob.glob("6seq-baseline-issdm*.csv"))
x = s.drop(s.index[range(0, 9)])
y = x.drop(x.index[range(40, len(x))])
y
# Out:
#                                  seconds  rate
# 9            45:45:45:45:45:45:45:45:45:  2859
# 10           50:50:50:50:50:50:50:50:50:  2938
# 11           55:55:55:55:55:55:55:55:55:  2853
# 12           60:60:60:60:60:60:60:60:60:  2906
# 13           65:65:65:65:65:65:65:65:65:  2993
# 14           70:70:70:70:70:70:70:70:70:  2880
# 15           75:75:75:75:75:75:75:75:75:  3010
# 16           80:80:80:80:80:80:80:80:80:  2962
# 17           85:85:85:85:85:85:85:85:85:  2960
# 18           90:90:90:90:90:90:90:90:90:  3024
# 19           95:95:95:95:95:95:95:95:95:  2967
# 20  100:100:100:100:100:100:100:100:100:  3001
# 21  105:105:105:105:105:105:105:105:105:  2950
# 22  110:110:110:110:110:110:110:110:110:  2945
# 23  115:115:115:115:115:115:115:115:115:  2941
# 24  120:120:120:120:120:120:120:120:120:  2989
# 25  125:125:125:125:125:125:125:125:125:  2934
# 26  130:130:130:130:130:130:130:130:130:  2978
# 27  135:135:135:135:135:135:135:135:135:  2969
# ...
